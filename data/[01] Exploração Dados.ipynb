# %%
import pandas as pd
import json

# %%
df = pd.read_json("raw/dataset.json")

# %% [markdown]
# # Exploração Inicial

# %%
df.head()
# Out:
#      loteria  concurso        data                              local  \
# 0   megasena    1551.0  27/11/2013            Auditório em OSASCO, SP
# 1  lotofacil     656.0  28/07/2011   Caminhão da Sorte em ROSEIRA, SP
# 2   megasena     664.0  14/05/2005    Caminhão da Sorte em PASSOS, MG
# 3        NaN       NaN         NaN                                NaN
# 4   megasena     366.0  01/06/2002  Caminhão da Sorte em Orlândia, SP
#
#                                  dezenasOrdemSorteio  \
# 0                           [02, 23, 38, 15, 21, 19]
# 1  [03, 18, 08, 14, 15, 05, 22, 09, 20, 07, 25, 1...
# 2                           [12, 01, 55, 59, 38, 36]
# 3                                                NaN
# 4                           [06, 04, 51, 07, 21, 15]
#
#                                              dezenas trevos timeCoracao  \
# 0                           [02, 15, 19, 21, 23, 38]   None         N/A
# 1  [02, 03, 05, 07, 08, 09, 11, 13, 14, 15, 18, 2...     []        None
# 2                           [01, 12, 36, 38, 55, 59]     []        None
# 3                                                NaN    NaN         NaN
# 4                           [04, 06, 07, 15, 21, 51]     []        None
#
#   mesSorte                                         premiacoes  ...  \
# 0     None  [{'descricao': '6 acertos', 'faixa': 1, 'ganha...  ...
# 1     None  [{'descricao': '15 acertos', 'faixa': 1, 'ganh...  ...
# 2     None  [{'descricao': '6 acertos', 'faixa': 1, 'ganha...  ...
# 3      NaN                                                NaN  ...
# 4     null  [{'descricao': '6 acertos', 'faixa': 1, 'ganha...  ...
#
#                                           observacao acumulou  \
# 0                Sorteio realizado em Estúdio de TV.      0.0
# 1                                                         0.0
# 2  ACUMULOU!!! Estimativa de prêmio (SENA) próxim...      1.0
# 3                                                NaN      NaN
# 4  Estimativa de prêmio (SENA) próximo concurso: ...      1.0
#
#    proximoConcurso  dataProximoConcurso  \
# 0           1552.0           30/11/2013
# 1            657.0           01/08/2011
# 2            665.0           18/05/2005
# 3              NaN                  NaN
# 4            367.0           05/06/2002
#
#                                      localGanhadores valorArrecadado  \
# 0  [{'ganhadores': 1, 'municipio': 'BOA VISTA', '...      26151116.0
# 1  [{'ganhadores': 1, 'municipio': 'MANACAPURU', ...      19064847.5
# 2                                                 []             0.0
# 3                                                NaN             NaN
# 4                                                 []             0.0
#
#    valorAcumuladoConcurso_0_5  valorAcumuladoConcursoEspecial  \
# 0                  4782195.52                     55716523.25
# 1                        0.00                            0.00
# 2                 23857740.39                            0.00
# 3                         NaN                             NaN
# 4                  5048832.63                            0.00
#
#    valorAcumuladoProximoConcurso  valorEstimadoProximoConcurso
# 0                           0.00                     3000000.0
# 1                           0.00                     1700000.0
# 2                    23857740.39                           0.0
# 3                            NaN                           NaN
# 4                      625880.91                           0.0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8176 entries, 0 to 8175
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   loteria                         8174 non-null   object
#  1   concurso                        8174 non-null   float64
#  2   data                            8174 non-null   object
#  3   local                           8174 non-null   object
#  4   dezenasOrdemSorteio             8174 non-null   object
#  5   dezenas                         8174 non-null   object
#  6   trevos                          7381 non-null   object
#  7   timeCoracao                     3099 non-null   object
#  8   mesSorte                        2296 non-null   object
#  9   premiacoes                      8174 non-null   object
#  10  estadosPremiados                7360 non-null   object
#  11  observacao                      8174 non-null   object
#  12  acumulou                        8174 non-null   float64
#  13  proximoConcurso                 8174 non-null   float64
#  14  dataProximoConcurso             8174 non-null   object
#  15  localGanhadores                 8174 non-null   object
#  16  valorArrecadado                 8174 non-null   float64
#  17  valorAcumuladoConcurso_0_5      8174 non-null   float64
#  18  valorAcumuladoConcursoEspecial  8174 non-null   float64
#  19  valorAcumuladoProximoConcurso   8174 non-null   float64
#  20  valorEstimadoProximoConcurso    8174 non-null   float64
# dtypes: float64(8), object(13)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#           concurso     acumulou  proximoConcurso  valorArrecadado  \
# count  8174.000000  8174.000000      8174.000000     8.174000e+03
# mean   1365.549670     0.590531      1366.549670     1.921821e+07
# std     929.131099     0.491766       929.131099     6.107406e+07
# min       1.000000     0.000000         2.000000     0.000000e+00
# 25%     565.000000     0.000000       566.000000     1.418518e+06
# 50%    1228.500000     1.000000      1229.500000     9.292944e+06
# 75%    2080.000000     1.000000      2081.000000     2.303729e+07
# max    3534.000000     1.000000      3535.000000     2.490297e+09
#
#        valorAcumuladoConcurso_0_5  valorAcumuladoConcursoEspecial  \
# count                8.174000e+03                    8.174000e+03
# mean                 3.804449e+06                    2.019212e+07
# std                  1.091996e+07                    3.089179e+07
# min                  0.000000e+00                    0.000000e+00
# 25%                  0.000000e+00                    0.000000e+00
# 50%                  2.010365e+05                    0.000000e+00
# 75%                  3.413749e+06                    3.545109e+07
# max                  2.670063e+08                    1.735093e+08
#
#        valorAcumuladoProximoConcurso  valorEstimadoProximoConcurso
# count                   8.174000e+03                  8.174000e+03
# mean                    9.341134e+06                  1.084534e+07
# std                     2.309683e+07                  2.788124e+07
# min                     0.000000e+00                  0.000000e+00
# 25%                     0.000000e+00                  1.200000e+06
# 50%                     1.114194e+06                  1.800000e+06
# 75%                     7.379924e+06                  7.000000e+06
# max                     2.670063e+08                  6.000000e+08

# %%
df['data'] = pd.to_datetime(df['data'], format='mixed', dayfirst=True)
df['dataProximoConcurso'] = pd.to_datetime(df['dataProximoConcurso'], format='mixed', dayfirst=True)

# %%
df['data'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8176 entries, 0 to 8175
# Series name: data
# Non-Null Count  Dtype
# --------------  -----
# 8174 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 64.0 KB

# %%
df.nunique().sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.nunique().sort_values()
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\frame.py:11863, in DataFrame.nunique(self, axis, dropna)
#   11825 def nunique(self, axis: Axis = 0, dropna: bool = True) -> Series:
#   11826     """
#   11827     Count number of distinct elements in specified axis.
#   11828
#    (...)  11861     dtype: int64
#   11862     """
# > 11863     return self.apply(Series.nunique, axis=axis, dropna=dropna)
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\base.py:1067, in IndexOpsMixin.nunique(self, dropna)
#    1032 @final
#    1033 def nunique(self, dropna: bool = True) -> int:
#    1034     """
#    1035     Return number of unique elements in the object.
#    1036
#    (...)   1065     4
#    1066     """
# -> 1067     uniqs = self.unique()
#    1068     if dropna:
#    1069         uniqs = remove_na_arraylike(uniqs)
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\series.py:2419, in Series.unique(self)
#    2356 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2357     """
#    2358     Return unique values of Series object.
#    2359
#    (...)   2417     Categories (3, object): ['a' < 'b' < 'c']
#    2418     """
# -> 2419     return super().unique()
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\base.py:1029, in IndexOpsMixin.unique(self)
#    1027     result = values.unique()
#    1028 else:
# -> 1029     result = algorithms.unique1d(values)
#    1030 return result
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)    399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File d:\Users\Paulo\Documents\Projetos\etl-loteria-federal\venv\Lib\site-packages\pandas\core\algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# File pandas/_libs/hashtable_class_helper.pxi:7260, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# File pandas/_libs/hashtable_class_helper.pxi:7203, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
