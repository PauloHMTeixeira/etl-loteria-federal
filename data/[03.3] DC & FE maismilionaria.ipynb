# %%
import pandas as pd
import json
import ast
import sqlite3

# %%
df = pd.read_csv("raw/milionaria.csv")

# %% [markdown]
# # mais milionaria

# %% [markdown]
# ## Limpeza e ajustes nos dados

# %%
df = df.reset_index()

# %%
loteria = df["loteria"].iloc[0]

if loteria in ["megasena", "lotofacil"]:
    colunas_drop = ["timeCoracao", "mesSorte", "trevos"]

elif loteria == "maismilionaria":
    colunas_drop = ["timeCoracao", "mesSorte"]

elif loteria == "timemania":
    colunas_drop = ["mesSorte", "trevos"]

elif loteria == "diadesorte":
    colunas_drop = ["timeCoracao", "trevos"]

else:
    colunas_drop = []


colunas_drop = [c for c in colunas_drop if c in df.columns]

df = df.drop(columns=colunas_drop)

# %%
df.head()
# Out:
#    index  Unnamed: 0         loteria  concurso        data  \
# 0      0          10  maismilionaria     241.0  12/04/2025
# 1      1          26  maismilionaria     246.0  30/04/2025
# 2      2          42  maismilionaria     160.0  03/07/2024
# 3      3          50  maismilionaria      62.0  22/07/2023
# 4      4          68  maismilionaria     280.0  27/08/2025
#
#                               local  \
# 0  Espaço da Sorte em SAO PAULO, SP
# 1  Espaço da Sorte em SAO PAULO, SP
# 2  Espaço da Sorte em SAO PAULO, SP
# 3  Espaço da Sorte em SAO PAULO, SP
# 4  Espaço da Sorte em SAO PAULO, SP
#
#                                 dezenasOrdemSorteio  \
# 0  ['50', '16', '27', '05', '48', '46', '02', '06']
# 1  ['50', '06', '17', '48', '40', '29', '03', '02']
# 2  ['11', '27', '10', '45', '32', '12', '04', '02']
# 3  ['29', '25', '47', '04', '35', '44', '05', '01']
# 4  ['37', '18', '29', '22', '25', '49', '04', '01']
#
#                                 dezenas      trevos  \
# 0  ['05', '16', '27', '46', '48', '50']  ['2', '6']
# 1  ['06', '17', '29', '40', '48', '50']  ['2', '3']
# 2  ['10', '11', '12', '27', '32', '45']  ['2', '4']
# 3  ['04', '25', '29', '35', '44', '47']  ['1', '5']
# 4  ['18', '22', '25', '29', '37', '49']  ['1', '4']
#
#                                           premiacoes  ... observacao  \
# 0  [{'descricao': '6 acertos + 2 trevos', 'faixa'...  ...        NaN
# 1  [{'descricao': '6 acertos + 2 trevos', 'faixa'...  ...        NaN
# 2  [{'descricao': '6 acertos + 2 trevos', 'faixa'...  ...        NaN
# 3  [{'descricao': '6 acertos + 2 trevos', 'faixa'...  ...        NaN
# 4  [{'descricao': '6 acertos + 2 trevos', 'faixa'...  ...        NaN
#
#    acumulou  proximoConcurso  dataProximoConcurso localGanhadores  \
# 0       1.0            242.0           16/04/2025              []
# 1       1.0            247.0           03/05/2025              []
# 2       1.0            161.0           06/07/2024              []
# 3       1.0             63.0           26/07/2023              []
# 4       1.0            281.0           30/08/2025              []
#
#   valorArrecadado  valorAcumuladoConcurso_0_5  valorAcumuladoConcursoEspecial  \
# 0      11681196.0                         0.0                             0.0
# 1      12107082.0                         0.0                             0.0
# 2      17088414.0                         0.0                             0.0
# 3       7530444.0                         0.0                             0.0
# 4      13447584.0                         0.0                             0.0
#
#    valorAcumuladoProximoConcurso  valorEstimadoProximoConcurso
# 0                   6.757004e+07                    68500000.0
# 1                   7.403604e+07                    75000000.0
# 2                   2.344953e+08                   236000000.0
# 3                   5.668095e+07                    57500000.0
# 4                   1.485751e+08                   150000000.0
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['index', 'Unnamed: 0', 'loteria', 'concurso', 'data', 'local',
#        'dezenasOrdemSorteio', 'dezenas', 'trevos', 'premiacoes',
#        'estadosPremiados', 'observacao', 'acumulou', 'proximoConcurso',
#        'dataProximoConcurso', 'localGanhadores', 'valorArrecadado',
#        'valorAcumuladoConcurso_0_5', 'valorAcumuladoConcursoEspecial',
#        'valorAcumuladoProximoConcurso', 'valorEstimadoProximoConcurso'],
#       dtype='object')

# %% [markdown]
# ### removendo concursos duplicados

# %%
if df.duplicated(subset=["concurso"]).sum():
    df = df.drop_duplicates(subset=["concurso"], keep="last")

# %% [markdown]
# ### corrigindo tipagem de colunas concurso e data (dayfirst por conta do formato brasileiro e mixed pois existem 27/02/2025 e 27-02-2025)

# %%
df["concurso"] = pd.to_numeric(df["concurso"], errors="coerce").astype("Int64")

# %%
df["data"] = pd.to_datetime(df["data"], dayfirst=True, format='mixed')
df["proximoConcurso"] = pd.to_datetime(df["proximoConcurso"], dayfirst=True, format='mixed')

# %% [markdown]
# ### corrigindo tipagem de colunas numéricas (dinheiro)

# %%
cols_monetarias = [
    "valorArrecadado",
    "valorAcumuladoConcurso_0_5",
    "valorAcumuladoConcursoEspecial",
    "valorAcumuladoProximoConcurso",
    "valorEstimadoProximoConcurso",
]

for c in cols_monetarias:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# %% [markdown]
# ### corrigindo booleanos

# %%
df["acumulou"] = df["acumulou"].astype("boolean")

# %% [markdown]
# ### normalizar colunas que são listas

# %%
def normalizar_lista(lista):
    if isinstance(lista, list):
        return lista
    if isinstance(lista, str):
        try:
            return ast.literal_eval(lista)
        except Exception as e:
            return None
    return None

# %%
df["dezenas"] = df["dezenas"].apply(normalizar_lista)
df["dezenasOrdemSorteio"] = df["dezenasOrdemSorteio"].apply(normalizar_lista)

expected_count = len(df.loc[0, "dezenas"])

# %%
df["premiacoes"] = df["premiacoes"].apply(normalizar_lista)

# %%
df["localGanhadores"] = df["localGanhadores"].apply(normalizar_lista)

# %% [markdown]
# ### valores ausentes
# - concursos sem ganhador (localGanhadores)
# - arrecadação sem nada (pode ser nulo)
# - premiações vazias (válido)
#
# Esses não precisam ser preenchidos

# %% [markdown]
# ### dezenas inválidas

# %%
select_invalido = df["dezenas"].apply(lambda x: isinstance(x, list) and len(x) != expected_count)

# %%
select_invalido.sum()
# Out:
# np.int64(0)

# %%
df = df[df["dezenas"].apply(lambda x: isinstance(x, list) and len(x) == expected_count)]

# %% [markdown]
# ### dezenas fora de 1 a 60

# %%
def dezenas_validas(lista, loteria):
    intervalos_dezenas = {
    "megasena": (1, 60),
    "lotofacil": (1, 25),
    "timemania": (1, 80),
    "diadesorte": (1, 31),
    "maismilionaria": (1, 50)
    }
    range_dezenas = intervalos_dezenas[loteria]
    if not isinstance(lista, list):
        return False
    return all(range_dezenas[0] <= int(n) <= range_dezenas[1] for n in lista)

# %%
df = df[df.apply(lambda row: dezenas_validas(row["dezenas"], row["loteria"]), axis=1)]

# %% [markdown]
# ### valor monetário negativo

# %%
for coluna in cols_monetarias:
    df = df[(df[coluna].isna()) | (df[coluna] >= 0)]

# %% [markdown]
# ## Engenharia de features

# %% [markdown]
# ### separando dia, mês, ano, semana do ano e dia da semana das colunas data e proximoConcurso

# %%
df['data_dia'] = df['data'].dt.day
df['data_mes'] = df['data'].dt.month
df['data_ano'] = df['data'].dt.year
df['semana_ano_concurso'] = df['data'].dt.isocalendar().week
df["dia_semana_concurso"] = df["data"].dt.weekday

df['proximoConcurso_dia'] = df['proximoConcurso'].dt.day
df['proximoConcurso_mes'] = df['proximoConcurso'].dt.month
df['proximoConcurso_ano'] = df['proximoConcurso'].dt.year

# %% [markdown]
# ### Separar cada número das dezenas sorteadas em colunas diferentes

# %%
df["qtd_dezenas"] = df["dezenas"].apply(lambda x: len(x) if isinstance(x, list) else 0)
max_dezenas = df["qtd_dezenas"].max()

# %%
max_dezenas
# Out:
# np.int64(6)

# %%
for i in range(max_dezenas):
    df[f"dezena_{i+1}"] = df["dezenas"].apply(
        lambda x: x[i] if isinstance(x, list) and len(x) > i else None
    )

# %%
df.drop(columns=["qtd_dezenas"], inplace=True)

# %% [markdown]
# ### Separar cidade e estado em colunas diferentes (local)

# %%
df[["nome_local", "resto"]] = df["local"].str.split(" em ", n=1, expand=True)

# %%
df[["cidade", "estado"]] = df["resto"].str.rsplit(", ", n=1, expand=True)

# %%
df.drop(columns=["resto"], inplace=True)

# %% [markdown]
# ### separar premiações em colunas, criar coluna com quantos premiados

# %%
df['premiacoes'][1]
# Out:
# [{'descricao': '6 acertos + 2 trevos',
#   'faixa': 1,
#   'ganhadores': 0,
#   'valorPremio': 0},
#  {'descricao': '6 acertos + 1 ou nenhum trevo',
#   'faixa': 2,
#   'ganhadores': 0,
#   'valorPremio': 0},
#  {'descricao': '5 acertos + 2 trevos',
#   'faixa': 3,
#   'ganhadores': 1,
#   'valorPremio': 428030.15},
#  {'descricao': '5 acertos + 1 ou nenhum trevo',
#   'faixa': 4,
#   'ganhadores': 28,
#   'valorPremio': 6794.13},
#  {'descricao': '4 acertos + 2 trevos',
#   'faixa': 5,
#   'ganhadores': 136,
#   'valorPremio': 1498.7},
#  {'descricao': '4 acertos + 1 ou nenhum trevo',
#   'faixa': 6,
#   'ganhadores': 1550,
#   'valorPremio': 131.49},
#  {'descricao': '3 acertos + 2 trevos',
#   'faixa': 7,
#   'ganhadores': 2307,
#   'valorPremio': 50},
#  {'descricao': '3 acertos + 1 trevo',
#   'faixa': 8,
#   'ganhadores': 18568,
#   'valorPremio': 24},
#  {'descricao': '2 acertos + 2 trevos',
#   'faixa': 9,
#   'ganhadores': 18229,
#   'valorPremio': 12},
#  {'descricao': '2 acertos + 1 trevo',
#   'faixa': 10,
#   'ganhadores': 143302,
#   'valorPremio': 6}]

# %%
df["premiacoes"] = df["premiacoes"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str)
    else (x if isinstance(x, list) else None)
)

# %%
def expandir_premiacoes(prem_list):
    """
    Recebe a lista de premiações e retorna um dicionário
    com colunas dinâmicas: ganhadores_faixaX e valor_faixaX.
    Funciona para qualquer loteria.
    """
    if not isinstance(prem_list, list):
        return {}

    resultado = {}

    for item in prem_list:
        # identificar faixa
        faixa = item.get("faixa")

        if faixa is None:
            continue

        # criar nomes de coluna dinâmicos
        col_ganhadores = f"ganhadores_faixa_{faixa}"
        col_valor = f"valor_faixa_{faixa}"

        resultado[col_ganhadores] = item.get("ganhadores")
        resultado[col_valor] = item.get("valorPremio")

    return resultado

# %%
premios_expandido = df["premiacoes"].apply(expandir_premiacoes)
premios_df = pd.DataFrame(premios_expandido.tolist())
df = pd.concat([df, premios_df], axis=1)

# %%
cols_ganhadores = [c for c in df.columns if c.startswith("ganhadores_faixa_")]
df["total_ganhadores"] = df[cols_ganhadores].sum(axis=1)


cols_valores = [c for c in df.columns if c.startswith("valor_faixa_")]
df["total_pago_premios"] = df[cols_valores].sum(axis=1)


df["media_premio_real"] = df["total_pago_premios"] / df["total_ganhadores"]

# %% [markdown]
# ### localGanhadores separar por coluna

# %%
df['localGanhadores'][0]
# Out:
# []

# %%
def normalizar_local(lista):
    if isinstance(lista, list):
        return lista
    return []

df["localGanhadores"] = df["localGanhadores"].apply(normalizar_local)

# %%
df["municipioGanhador"] = df["localGanhadores"].apply(
    lambda x: x[0].get("municipio") if len(x) > 0 else None
)

df["ufGanhador"] = df["localGanhadores"].apply(
    lambda x: x[0].get("uf") if len(x) > 0 else None
)

# %%
def is_ticket_online(x):
    if len(x) == 0:
        return False
    registro = x[0]
    municipio = registro.get("municipio", "").strip().upper()
    uf = registro.get("uf", "").strip().upper()

    return municipio == "CANAL ELETRONICO" or uf == "BR"

df["ticketGanhadorOnline"] = df["localGanhadores"].apply(is_ticket_online)

# %%
df['ticketGanhadorOnline'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 234 entries, 0 to 233
# Series name: ticketGanhadorOnline
# Non-Null Count  Dtype
# --------------  -----
# 234 non-null    bool
# dtypes: bool(1)
# memory usage: 366.0 bytes

# %%
df['ufGanhador'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 234 entries, 0 to 233
# Series name: ufGanhador
# Non-Null Count  Dtype
# --------------  -----
# 1 non-null      object
# dtypes: object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# ### verificar diferença entre nulo e 0 em valorArrecadado

# %%
df['valorArrecadado']
# Out:
# 0      11681196.0
# 1      12107082.0
# 2      17088414.0
# 3       7530444.0
# 4      13447584.0
#           ...
# 229     3757236.0
# 230    16981584.0
# 231     4967928.0
# 232    15390600.0
# 233     4585338.0
# Name: valorArrecadado, Length: 234, dtype: float64

# %%
df["valorArrecadado"] = df["valorArrecadado"].replace(0, None)

# %% [markdown]
# ### criar coluna de razão entre valor estimado e valor acumulado

# %%
def calcular_razao(row):
    acumulado = row["valorAcumuladoProximoConcurso"]
    estimado  = row["valorEstimadoProximoConcurso"]

    # evita problemas de None, NaN ou divisões por zero
    if acumulado is None or pd.isna(acumulado) or acumulado == 0:
        return None
    if estimado is None or pd.isna(estimado):
        return None

    return estimado / acumulado

df["razaoEstimadoAcumulado"] = df.apply(calcular_razao, axis=1)

# %% [markdown]
# ### colunas extras

# %%
def normalizar_dezenas(lista):
    if not isinstance(lista, list):
        return None
    nova = []
    for item in lista:
        try:
            nova.append(int(item))  # converte "03" → 3
        except:
            return None  # caso algo esteja muito errado
    return nova

df["dezenas"] = df["dezenas"].apply(normalizar_dezenas)

# %%
df["qtd_pares"] = df["dezenas"].apply(
    lambda x: sum(1 for n in x if n % 2 == 0) if isinstance(x, list) else None
)

df["qtd_impares"] = df["dezenas"].apply(
    lambda x: sum(1 for n in x if n % 2 != 0) if isinstance(x, list) else None
)


df["range_dezenas"] = df["dezenas"].apply(
    lambda x: max(x) - min(x) if isinstance(x, list) and len(x) == 6 else None
)

# %% [markdown]
# # SQLite

# %%
conn = sqlite3.connect("loterias.db")

# %%
nome_loteria = df['loteria'][0]

# %%
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, list)).any():
        df[col] = df[col].apply(json.dumps)

# %%
df.to_sql(
    name=nome_loteria,
    con=conn,
    if_exists="replace",
    index=False
)
# Out:
# 234

# %%
conn.close()

# %% [markdown]
# ## Acessando e testando

# %%
conn = sqlite3.connect("loterias.db")
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
cursor.fetchall()
# Out:
# [('diadesorte',),
#  ('timemania',),
#  ('megasena',),
#  ('lotofacil',),
#  ('maismilionaria',)]

# %%
cursor.execute("PRAGMA table_info(diadesorte);")
cursor.fetchall()
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'Unnamed: 0', 'INTEGER', 0, None, 0),
#  (2, 'loteria', 'TEXT', 0, None, 0),
#  (3, 'concurso', 'INTEGER', 0, None, 0),
#  (4, 'data', 'TIMESTAMP', 0, None, 0),
#  (5, 'local', 'TEXT', 0, None, 0),
#  (6, 'dezenasOrdemSorteio', 'TEXT', 0, None, 0),
#  (7, 'dezenas', 'TEXT', 0, None, 0),
#  (8, 'mesSorte', 'TEXT', 0, None, 0),
#  (9, 'premiacoes', 'TEXT', 0, None, 0),
#  (10, 'estadosPremiados', 'TEXT', 0, None, 0),
#  (11, 'observacao', 'TEXT', 0, None, 0),
#  (12, 'acumulou', 'INTEGER', 0, None, 0),
#  (13, 'proximoConcurso', 'TIMESTAMP', 0, None, 0),
#  (14, 'dataProximoConcurso', 'TEXT', 0, None, 0),
#  (15, 'localGanhadores', 'TEXT', 0, None, 0),
#  (16, 'valorArrecadado', 'REAL', 0, None, 0),
#  (17, 'valorAcumuladoConcurso_0_5', 'REAL', 0, None, 0),
#  (18, 'valorAcumuladoConcursoEspecial', 'REAL', 0, None, 0),
#  (19, 'valorAcumuladoProximoConcurso', 'REAL', 0, None, 0),
#  (20, 'valorEstimadoProximoConcurso', 'REAL', 0, None, 0),
#  (21, 'data_dia', 'INTEGER', 0, None, 0),
#  (22, 'data_mes', 'INTEGER', 0, None, 0),
#  (23, 'data_ano', 'INTEGER', 0, None, 0),
#  (24, 'semana_ano_concurso', 'INTEGER', 0, None, 0),
#  (25, 'dia_semana_concurso', 'INTEGER', 0, None, 0),
#  (26, 'proximoConcurso_dia', 'INTEGER', 0, None, 0),
#  (27, 'proximoConcurso_mes', 'INTEGER', 0, None, 0),
#  (28, 'proximoConcurso_ano', 'INTEGER', 0, None, 0),
#  (29, 'dezena_1', 'TEXT', 0, None, 0),
#  (30, 'dezena_2', 'TEXT', 0, None, 0),
#  (31, 'dezena_3', 'TEXT', 0, None, 0),
#  (32, 'dezena_4', 'TEXT', 0, None, 0),
#  (33, 'dezena_5', 'TEXT', 0, None, 0),
#  (34, 'dezena_6', 'TEXT', 0, None, 0),
#  (35, 'dezena_7', 'TEXT', 0, None, 0),
#  (36, 'nome_local', 'TEXT', 0, None, 0),
#  (37, 'cidade', 'TEXT', 0, None, 0),
#  (38, 'estado', 'TEXT', 0, None, 0),
#  (39, 'ganhadores_faixa_1', 'INTEGER', 0, None, 0),
#  (40, 'valor_faixa_1', 'REAL', 0, None, 0),
#  (41, 'ganhadores_faixa_2', 'INTEGER', 0, None, 0),
#  (42, 'valor_faixa_2', 'REAL', 0, None, 0),
#  (43, 'ganhadores_faixa_3', 'INTEGER', 0, None, 0),
#  (44, 'valor_faixa_3', 'INTEGER', 0, None, 0),
#  (45, 'ganhadores_faixa_4', 'INTEGER', 0, None, 0),
#  (46, 'valor_faixa_4', 'INTEGER', 0, None, 0),
#  (47, 'ganhadores_faixa_5', 'INTEGER', 0, None, 0),
#  (48, 'valor_faixa_5', 'REAL', 0, None, 0),
#  (49, 'total_ganhadores', 'INTEGER', 0, None, 0),
#  (50, 'total_pago_premios', 'REAL', 0, None, 0),
#  (51, 'media_premio_real', 'REAL', 0, None, 0),
#  (52, 'municipioGanhador', 'TEXT', 0, None, 0),
#  (53, 'ufGanhador', 'TEXT', 0, None, 0),
#  (54, 'ticketGanhadorOnline', 'INTEGER', 0, None, 0),
#  (55, 'razaoEstimadoAcumulado', 'REAL', 0, None, 0),
#  (56, 'qtd_pares', 'INTEGER', 0, None, 0),
#  (57, 'qtd_impares', 'INTEGER', 0, None, 0),
#  (58, 'range_dezenas', 'TEXT', 0, None, 0)]

# %%
cursor.execute("SELECT * FROM diadesorte LIMIT 5;")
cursor.fetchall()
# Out:
# [(0,
#   39,
#   'diadesorte',
#   480,
#   '2021-07-13 00:00:00',
#   'ESPAÇO LOTERIAS CAIXA em SÃO PAULO, SP',
#   '["10", "20", "03", "28", "06", "31", "17"]',
#   '[3, 6, 10, 17, 20, 28, 31]',
#   'Setembro',
#   '[{"descricao": "7 acertos", "faixa": 1, "ganhadores": 0, "valorPremio": 0}, {"descricao": "6 acertos", "faixa": 2, "ganhadores": 53, "valorPremio": 1554.29}, {"descricao": "5 acertos", "faixa": 3, "ganhadores": 1918, "valorPremio": 20}, {"descricao": "4 acertos", "faixa": 4, "ganhadores": 22840, "valorPremio": 4}, {"descricao": "M\\u00eas da Sorte", "faixa": 5, "ganhadores": 86382, "valorPremio": 2}]',
#   '[]',
#   None,
#   1,
#   '1970-01-01 00:00:00',
#   '15/07/2021',
#   '[]',
#   1602668.0,
#   0.0,
#   0.0,
#   593996.86,
#   800000.0,
#   13,
#   7,
#   2021,
#   28,
#   1,
#   1,
#   1,
#   1970,
#   '03',
#   '06',
#   '10',
#   '17',
#   '20',
#   '28',
#   '31',
#   'ESPAÇO LOTERIAS CAIXA',
#   'SÃO PAULO',
#   'SP',
#   0,
#   0.0,
#   53,
#   1554.29,
#   1918,
#   20,
#   22840,
#   4,
#   86382,
#   2.0,
#   111193,
#   1580.29,
#   0.014212135656021512,
#   None,
#   None,
#   0,
#   1.3468084662939128,
#   4,
#   3,
#   None),
#  (1,
#   46,
#   'diadesorte',
#   519,
#   '2021-10-16 00:00:00',
#   'ESPAÇO LOTERIAS CAIXA em SÃO PAULO, SP',
#   '["08", "19", "24", "13", "16", "12", "09"]',
#   '[8, 9, 12, 13, 16, 19, 24]',
#   'Novembro',
#   '[{"descricao": "7 acertos", "faixa": 1, "ganhadores": 1, "valorPremio": 1836760.82}, {"descricao": "6 acertos", "faixa": 2, "ganhadores": 99, "valorPremio": 1460.46}, {"descricao": "5 acertos", "faixa": 3, "ganhadores": 3363, "valorPremio": 20}, {"descricao": "4 acertos", "faixa": 4, "ganhadores": 39933, "valorPremio": 4}, {"descricao": "M\\u00eas da Sorte", "faixa": 5, "ganhadores": 109242, "valorPremio": 2}]',
#   '[]',
#   None,
#   0,
#   '1970-01-01 00:00:00',
#   '19/10/2021',
#   '[{"ganhadores": 1, "municipio": "PINHEIROS", "nomeFatansiaUL": "", "serie": "", "posicao": 1, "uf": "ES"}]',
#   2615860.0,
#   0.0,
#   0.0,
#   0.0,
#   200000.0,
#   16,
#   10,
#   2021,
#   41,
#   5,
#   1,
#   1,
#   1970,
#   '08',
#   '09',
#   '12',
#   '13',
#   '16',
#   '19',
#   '24',
#   'ESPAÇO LOTERIAS CAIXA',
#   'SÃO PAULO',
#   'SP',
#   1,
#   1836760.82,
#   99,
#   1460.46,
#   3363,
#   20,
#   39933,
#   4,
#   109242,
#   2.0,
#   152638,
#   1838247.28,
#   12.043182431635636,
#   'PINHEIROS',
#   'ES',
#   0,
#   None,
#   4,
#   3,
#   None),
#  (2,
#   84,
#   'diadesorte',
#   1132,
#   '2025-10-23 00:00:00',
#   'ESPAÇO DA SORTE em SÃO PAULO, SP',
#   '["06", "13", "17", "29", "04", "23", "26"]',
#   '[4, 6, 13, 17, 23, 26, 29]',
#   'Janeiro',
#   '[{"descricao": "7 acertos", "faixa": 1, "ganhadores": 1, "valorPremio": 4761847.69}, {"descricao": "6 acertos", "faixa": 2, "ganhadores": 206, "valorPremio": 2063.28}, {"descricao": "5 acertos", "faixa": 3, "ganhadores": 5707, "valorPremio": 25}, {"descricao": "4 acertos", "faixa": 4, "ganhadores": 60760, "valorPremio": 5}, {"descricao": "M\\u00eas da Sorte", "faixa": 5, "ganhadores": 159250, "valorPremio": 2.5}]',
#   '[]',
#   None,
#   0,
#   '1970-01-01 00:00:00.000001',
#   '25/10/2025',
#   '[{"ganhadores": 1, "municipio": "IGARASSU", "nomeFatansiaUL": "", "serie": "", "posicao": 1, "uf": "PE"}]',
#   5164162.5,
#   0.0,
#   0.0,
#   0.0,
#   200000.0,
#   23,
#   10,
#   2025,
#   43,
#   3,
#   1,
#   1,
#   1970,
#   '04',
#   '06',
#   '13',
#   '17',
#   '23',
#   '26',
#   '29',
#   'ESPAÇO DA SORTE',
#   'SÃO PAULO',
#   'SP',
#   1,
#   4761847.69,
#   206,
#   2063.28,
#   5707,
#   25,
#   60760,
#   5,
#   159250,
#   2.5,
#   225924,
#   4763943.470000001,
#   21.08648691595404,
#   'IGARASSU',
#   'PE',
#   0,
#   None,
#   3,
#   4,
#   None),
#  (3,
#   86,
#   'diadesorte',
#   912,
#   '2024-05-11 00:00:00',
#   'ESPAÇO DA SORTE em SÃO PAULO, SP',
#   '["15", "11", "20", "14", "04", "31", "10"]',
#   '[4, 10, 11, 14, 15, 20, 31]',
#   'Dezembro',
#   '[{"descricao": "7 acertos", "faixa": 1, "ganhadores": 1, "valorPremio": 386110.48}, {"descricao": "6 acertos", "faixa": 2, "ganhadores": 27, "valorPremio": 3305.46}, {"descricao": "5 acertos", "faixa": 3, "ganhadores": 1188, "valorPremio": 25}, {"descricao": "4 acertos", "faixa": 4, "ganhadores": 15166, "valorPremio": 5}, {"descricao": "M\\u00eas da Sorte", "faixa": 5, "ganhadores": 42706, "valorPremio": 2.5}]',
#   '[]',
#   None,
#   0,
#   '1970-01-01 00:00:00',
#   '14/05/2024',
#   '[{"ganhadores": 1, "municipio": "SALTO", "nomeFatansiaUL": "", "serie": "", "posicao": 1, "uf": "SP"}]',
#   1470087.5,
#   0.0,
#   0.0,
#   0.0,
#   150000.0,
#   11,
#   5,
#   2024,
#   19,
#   5,
#   1,
#   1,
#   1970,
#   '04',
#   '10',
#   '11',
#   '14',
#   '15',
#   '20',
#   '31',
#   'ESPAÇO DA SORTE',
#   'SÃO PAULO',
#   'SP',
#   1,
#   386110.48,
#   27,
#   3305.46,
#   1188,
#   25,
#   15166,
#   5,
#   42706,
#   2.5,
#   59088,
#   389448.44,
#   6.590990387219063,
#   'SALTO',
#   'SP',
#   0,
#   None,
#   4,
#   3,
#   None),
#  (4,
#   91,
#   'diadesorte',
#   981,
#   '2024-10-26 00:00:00',
#   'ESPAÇO DA SORTE em SÃO PAULO, SP',
#   '["04", "10", "28", "08", "02", "01", "12"]',
#   '[1, 2, 4, 8, 10, 12, 28]',
#   'Dezembro',
#   '[{"descricao": "7 acertos", "faixa": 1, "ganhadores": 0, "valorPremio": 0}, {"descricao": "6 acertos", "faixa": 2, "ganhadores": 55, "valorPremio": 2030.85}, {"descricao": "5 acertos", "faixa": 3, "ganhadores": 1977, "valorPremio": 25}, {"descricao": "4 acertos", "faixa": 4, "ganhadores": 21253, "valorPremio": 5}, {"descricao": "M\\u00eas da Sorte", "faixa": 5, "ganhadores": 66556, "valorPremio": 2.5}]',
#   '[]',
#   None,
#   1,
#   '1970-01-01 00:00:00',
#   '29/10/2024',
#   '[]',
#   1969940.0,
#   0.0,
#   0.0,
#   865315.72,
#   1100000.0,
#   26,
#   10,
#   2024,
#   43,
#   5,
#   1,
#   1,
#   1970,
#   '01',
#   '02',
#   '04',
#   '08',
#   '10',
#   '12',
#   '28',
#   'ESPAÇO DA SORTE',
#   'SÃO PAULO',
#   'SP',
#   0,
#   0.0,
#   55,
#   2030.85,
#   1977,
#   25,
#   21253,
#   5,
#   66556,
#   2.5,
#   89841,
#   2063.35,
#   0.022966685588984983,
#   None,
#   None,
#   0,
#   1.2712123154309505,
#   6,
#   1,
#   None)]

# %%
cursor.execute("SELECT concurso, data, total_ganhadores FROM diadesorte LIMIT 10;")
cursor.fetchall()
# Out:
# [(480, '2021-07-13 00:00:00', 111193),
#  (519, '2021-10-16 00:00:00', 152638),
#  (1132, '2025-10-23 00:00:00', 225924),
#  (912, '2024-05-11 00:00:00', 59088),
#  (981, '2024-10-26 00:00:00', 89841),
#  (375, '2020-10-29 00:00:00', 91274),
#  (867, '2024-01-25 00:00:00', 84152),
#  (541, '2021-12-09 00:00:00', 94112),
#  (625, '2022-07-05 00:00:00', 77444),
#  (146, '2019-05-04 00:00:00', 144862)]

# %%
df_sql = pd.read_sql("SELECT * FROM diadesorte", conn)

# %%
df_sql = pd.read_sql(
    "SELECT concurso, data, total_ganhadores FROM diadesorte WHERE total_ganhadores > 100",
    conn
)

# %%
df_sql
# Out:
#      concurso                 data  total_ganhadores
# 0         480  2021-07-13 00:00:00            111193
# 1         519  2021-10-16 00:00:00            152638
# 2        1132  2025-10-23 00:00:00            225924
# 3         912  2024-05-11 00:00:00             59088
# 4         981  2024-10-26 00:00:00             89841
# ..        ...                  ...               ...
# 911        40  2018-08-21 00:00:00            311097
# 912       862  2024-01-13 00:00:00             81278
# 913       402  2021-01-05 00:00:00            130941
# 914       488  2021-07-31 00:00:00             67892
# 915       676  2022-11-01 00:00:00             55919
#
# [916 rows x 3 columns]
